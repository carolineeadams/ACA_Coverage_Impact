# %%
import pandas as pd
import numpy as np
from plotnine import *

# %%
aca_dta=pd.read_csv("/Users/carolineadams/Documents/Personal Projects/ACA_Coverage_Impact/ACA_Coverage_Impact/Data/states.csv")

# %%
aca_dta
# Out:
#                    State Uninsured Rate (2010) Uninsured Rate (2015)  \
# 0               Alabama                  14.6%                 10.1%
# 1                Alaska                  19.9%                 14.9%
# 2               Arizona                  16.9%                 10.8%
# 3              Arkansas                  17.5%                  9.5%
# 4             California                 18.5%                  8.6%
# 5               Colorado                 15.9%                  8.1%
# 6            Connecticut                  9.1%                    6%
# 7              Delaware                   9.7%                  5.9%
# 8   District of Columbia                  7.6%                  3.8%
# 9               Florida                  21.3%                 13.3%
# 10              Georgia                  19.7%                 13.9%
# 11                Hawaii                  7.9%                    4%
# 12                 Idaho                 17.7%                   11%
# ...

# %%
type(aca_dta['Uninsured Rate Change (2010-2015)'])
aca_dta['Uninsured Rate Change (2010-2015)']=aca_dta['Uninsured Rate Change (2010-2015)'].str.replace('%', "")
aca_dta['Uninsured Rate Change (2010-2015)']
# Out:
# 0       -4.5
# 1         -5
# 2       -6.1
# 3         -8
# 4       -9.9
# 5       -7.8
# 6       -3.1
# 7       -3.8
# 8       -3.8
# 9         -8
# 10      -5.8
# 11      -3.9
# 12      -6.7
# 13      -6.7
# 14      -5.2
# 15      -4.3
# 16      -4.8
# 17      -9.3
# 18      -5.9
# 19      -1.7
# 20      -4.7
# 21      -1.6
# 22      -6.3
# 23      -4.6
# 24      -5.5
# 25      -3.4
# 26      -5.7
# 27      -3.3
# 28     -10.3
# 29      -4.8
# 30      -4.5
# 31      -8.7
# 32      -4.8
# 33      -5.6
# 34        -2
# 35      -5.8
# 36        -5
# 37     -10.1
# 38      -3.8
# 39      -6.5
# 40      -6.6
# 41      -2.2
# 42      -4.1
# 43      -6.6
# 44      -4.8
# 45      -4.2
# 46        -4
# 47      -7.6
# 48      -8.6
# 49      -3.7
# 50      -3.4
# 51        6.1
# Name: Uninsured Rate Change (2010-2015), dtype: object

# %%
aca_dta
# Out:
#                    State Uninsured Rate (2010) Uninsured Rate (2015)  \
# 0               Alabama                  14.6%                 10.1%
# 1                Alaska                  19.9%                 14.9%
# 2               Arizona                  16.9%                 10.8%
# 3              Arkansas                  17.5%                  9.5%
# 4             California                 18.5%                  8.6%
# 5               Colorado                 15.9%                  8.1%
# 6            Connecticut                  9.1%                    6%
# 7              Delaware                   9.7%                  5.9%
# 8   District of Columbia                  7.6%                  3.8%
# 9               Florida                  21.3%                 13.3%
# 10              Georgia                  19.7%                 13.9%
# 11                Hawaii                  7.9%                    4%
# 12                 Idaho                 17.7%                   11%
# ...

# %%
aca_dta['Uninsured Rate Change (2010-2015)']=pd.to_numeric(aca_dta['Uninsured Rate Change (2010-2015)'])

uninsured_rate_exp_status=aca_dta.groupby("State Medicaid Expansion (2016)")['Uninsured Rate Change (2010-2015)'].mean()

# %%
uninsured_rate_exp_status
# Out:
# State Medicaid Expansion (2016)
# False   -4.721053
# True    -5.856250
# Name: Uninsured Rate Change (2010-2015), dtype: float64

# %%
uninsured_rate_exp_status=uninsured_rate_exp_status.to_frame()
uninsured_rate_exp_status
# Out:
#                                  Uninsured Rate Change (2010-2015)
# State Medicaid Expansion (2016)
# False                                                    -4.721053
# True                                                     -5.856250

# %%
(ggplot(aca_dta, aes(x="Medicaid Enrollment (2016)", y="Uninsured Rate (2015)")) +
geom_point())
# Out:
# <ggplot: (8762874253240)>

# %%
aca_dta['Uninsured Rate (2015)']=aca_dta['Uninsured Rate (2015)'].str.replace('%', "")
aca_dta['Uninsured Rate (2015)']=pd.to_numeric(aca_dta['Uninsured Rate (2015)'])

uninsured_exp_status_15=aca_dta.groupby("State Medicaid Expansion (2016)")['Uninsured Rate (2015)'].mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-d7c8e51556b9> in <module>
# ----> 1 aca_dta['Uninsured Rate (2015)']=aca_dta['Uninsured Rate (2015)'].str.replace('%', "")
#       2 aca_dta['Uninsured Rate (2015)']=pd.to_numeric(aca_dta['Uninsured Rate (2015)'])
#       3
#       4 uninsured_exp_status_15=aca_dta.groupby("State Medicaid Expansion (2016)")['Uninsured Rate (2015)'].mean()
#       5 uninsured_exp_status_15=uninsured_exp_status_15.to_frame()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ...

# %%
uninsured_exp_status_15=uninsured_exp_status_15.to_frame()
uninsured_exp_status_15
# Out:
#                                  Uninsured Rate (2015)
# State Medicaid Expansion (2016)
# False                                        10.889474
# True                                          7.434375

# %%
aca_dta['Uninsured Rate (2010)']=aca_dta['Uninsured Rate (2010)'].str.replace('%', "")
aca_dta['Uninsured Rate (2010)']=pd.to_numeric(aca_dta['Uninsured Rate (2010)'])

uninsured_exp_status_10=aca_dta.groupby("State Medicaid Expansion (2016)")['Uninsured Rate (2010)'].mean()
uninsured_exp_status_10=uninsured_exp_status_10.to_frame()
uninsured_exp_status_10
# Out:
#                                  Uninsured Rate (2010)
# State Medicaid Expansion (2016)
# False                                        15.610526
# True                                         13.290625
